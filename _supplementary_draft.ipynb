# %%
# %matplotlib inline
from figures.final_paper.supplementary import reverse_replay_lif_demo

reverse_replay_lif_demo(
    SEED=0,
    SEQ_REVS=[
        [(-3, -3), (-2, -2), (-1, -1), (-1, 1), (-1, 3), (-1, 5)],
        [(-3, -3), (-3, -1), (-3, 1), (-3, 3), (-2, 4), (-1, 5)],
    ],
    NODE_ORDER=[(-3, -3), (-2, -2), (-1, -1), (-1, 1), (-1, 3), (-3, -1), (-3, 1), (-3, 3), (-2, 4), (-1, 5)],
    NETWORK_SIZE_LIF=5, DT=0.0001, OFFSET=4,
    W_PP=0.42, W_PM=0.03, W_PI=1, W_MP=200, W_MM=.16, W_IP=50,
    TAU_P=0.02, TAU_M=0.02, TAU_I=0.01,
    V_REST_P=-0.075, V_REST_M=-0.065, V_REST_I=-0.065,
    V_TH_P=-0.045, V_TH_M=-0.045, V_TH_I=-0.045,
    V_RESET_P=-0.075, V_RESET_M=-0.065, V_RESET_I=-0.065,
    RP_P=0.1, RP_M=0.002, RP_I=0.002,
    TAUS_SYN={'ampa': 0.002, 'nmda': 0.08, 'gaba': 0.005},
    V_REVS_SYN={'ampa': 0, 'nmda': 0, 'gaba': -0.08},
    SEQ_START=0.1, SEQ_DUR=0.4, SEQ_STAGGER=0.2, SEQ_AMP=20, SEQ_FREQ=1000,
    REPLAY_START_FOR=2, REPLAY_START_REV=2.75, REPLAY_DUR=0.001, REPLAY_AMP=5, REPLAY_FREQ=10000,
    RESET_START=3.5, RESET_DUR=0.1, RESET_AMP=50, RESET_FREQ=1000,
    BKGD_GABAS=[
        {'start': 0, 'end': 1.5, 'amp': 1, 'freq': 10000,},
        {'start': 1.5, 'end': 4, 'amp': .001, 'freq': 10000,},
    ]).savefig('figure_bases/lif_reverse_replay.pdf', dpi=300);
