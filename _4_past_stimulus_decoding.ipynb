# %%
# %matplotlib inline
from figures import mutual_info_past_stim_current_sequence_vs_weights as fig_1

# %%
CONFIG = {
    'SEED': 0,
    
    'N_NODES': 100,
    'P_CONNECT': 0.2,
    'STRENGTHS': [1],
    'P_STRENGTHS': [1],
    
    'G_W': 5,
    'G_X': 15,
    'G_D': 20,
    'T_X': 20,
    
    'PAST_SEQUENCE_LENGTH': 4,
    'CURRENT_SEQUENCE_LENGTH': 4,
    
    'MC_SAMPLE_SIZES': [100, 100, 100, 100],
    
    'N_TRIALS': 60,

    'FIG_SIZE': (12, 6),
    'VISUAL_SCATTER': 0.02,
    'MARKER_SIZE': 50,
    'COLORS': ['k', 'b', 'g', 'r'],
    'FONT_SIZE': 16,
}

# %%
fig_1(**CONFIG)
# Out:
# pairwise t-values
#                matched       zero    random half_matched
# matched              0   9.991788  16.29829      8.73155
# zero         -9.991788          0   6.64619    0.2754723
# random       -16.29829   -6.64619         0    -5.442156
# half_matched  -8.73155 -0.2754723  5.442156            0
# pairwise p-values
#                    matched          zero        random  half_matched
# matched                  1  2.097642e-17  5.410179e-32  1.957875e-14
# zero          2.097642e-17             1  9.790184e-10     0.7834352
# random        5.410179e-32  9.790184e-10             1  2.900411e-07
# half_matched  1.957875e-14     0.7834352  2.900411e-07             1

# %% [markdown]
# #### Figure 1: Mutual information between previous stimulus sequence and current network activation sequence
# When the network connectivity matches the stimulus transition distribution, the spontaneous activity subsequent to a stimulus sequence has more information about that stimulus sequence than when the network connectivity is zero, random, or only half-matched to the stimulus transitions.

# %%
from figures import decoding_past_stim_from_present_activity as fig_2

# %%
CONFIG = {
    'SEED': 1,
    
    'N_NODES': 100,
    'P_CONNECT': 0.2,
    'STRENGTHS': [1, 2],
    'P_STRENGTHS': [0.5, 0.5],
    
    'G_W': 5,
    'G_X': 15,
    'G_D': 20,
    'T_X': 20,
    
    'DRIVEN_RUN_LENGTH': 6,
    'DRIVEN_RECORD_START': 0,
    'DRIVEN_RECORD_END': 6,
    'SPONT_RUN_LENGTH': 6,
    'SPONT_RECORD_START': 0,
    
    'N_TRIALS': 2000,
    
    'FIG_SIZE': (12, 4),
    'VISUAL_SCATTER': 0.02,
    'MARKER_SIZE': 50,
    'COLORS': ['k', 'r', 'b', 'g'],
    'FONT_SIZE': 16,
}

# %%
fig_2(**CONFIG)
# Out:
# pairwise t-values
#                matched      zero    random half_matched
# matched              0 -35.98619 -32.18727    -21.04399
# zero          35.98619         0  5.184899     18.11664
# random        32.18727 -5.184899         0     13.25501
# half_matched  21.04399 -18.11664 -13.25501            0
# pairwise p-values
#                     matched           zero         random  half_matched
# matched                   1  6.441881e-246  2.509192e-202  2.510419e-93
# zero          6.441881e-246              1   2.268263e-07  1.458168e-70
# random        2.509192e-202   2.268263e-07              1  2.813113e-39
# half_matched   2.510419e-93   1.458168e-70   2.813113e-39             1
